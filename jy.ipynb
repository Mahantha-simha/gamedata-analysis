# %%
import pandas as pd
import numpy as np

pd.set_option('future.no_silent_downcasting', True)
pd.set_option('display.max_columns', None)


df1 = pd.read_json('GameFactMockData2.json')
df=pd.json_normalize(df1['gamefact_data'])

# %%
df.replace('None', np.nan, inplace=True)
df.replace('Invalid', np.nan, inplace=True)

# %%
dro = df[df[['EventID', 'StadiumID', 'RefereeID', 'TimeID', 'DateID']].isna().any(axis=1)].index
df.drop(dro, inplace=True)

# %%
df.head()
# Out:
#    EventID  StadiumID RefereeID  GameID TimeID DateID PauseID HighlightID  \
# 1       10         10         5      89   4674   1500       2          10
# 3       10         10         1      90   6000     15     NaN           3
# 11      12         17         8      98  13000     33      10          12
#
#     GameDuration GameNumberOfPause GameTeam GameInterruption  \
# 1             34                 3     blue                1
# 3             -5                 2      red               -1
# 11            85               NaN     blue              NaN
#
#    GameMinuteOfPause GameDurationOfPause GameResult
# 1                 24                  23  blue wins
# 3                NaN                 NaN  blue wins
# 11                40                  30  blue wins

# %%
a=df[df['GameDuration'] < 0]
df.drop(a.index, inplace=True)

# %%
df.shape
# Out:
# (0, 15)

# %%
cols_to_int = ['EventID', 'RefereeID', 'TimeID', 'DateID', 'PauseID','HighlightID', 'GameDuration','GameNumberOfPause', 'GameInterruption', 'GameMinuteOfPause', 'GameDurationOfPause']
df[cols_to_int] = df[cols_to_int].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EventID              0 non-null      int64
#  1   StadiumID            0 non-null      int64
#  2   RefereeID            0 non-null      int64
#  3   GameID               0 non-null      int64
#  4   TimeID               0 non-null      int64
#  5   DateID               0 non-null      int64
#  6   PauseID              0 non-null      int64
#  7   HighlightID          0 non-null      int64
#  8   GameDuration         0 non-null      int64
#  9   GameNumberOfPause    0 non-null      int64
#  10  GameTeam             0 non-null      object
#  11  GameInterruption     0 non-null      int64
#  12  GameMinuteOfPause    0 non-null      int64
#  13  GameDurationOfPause  0 non-null      int64
#  14  GameResult           0 non-null      object
# dtypes: int64(13), object(2)
# memory usage: 0.0+ bytes

# %%
df.to_csv('GameFactMockData2.csv', index=False)
